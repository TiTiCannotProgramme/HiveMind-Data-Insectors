# %%
import torch, torchvision
import sys # Python system library needed to load custom functions
import math # module with access to mathematical functions
import os # for changing the directory

import numpy as np  # for performing calculations on numerical arrays
import pandas as pd  # home of the DataFrame construct, _the_ most important object for Data Science
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt  # allows creation of insightful plots

sys.path.append('../../audio_preprocessing')
sys.path.append('../../src')
sys.path.append('../../model_training_utils')


import preprocessing_func_3
from generator_to_dataset_3 import NormalisedDataSet
from gdsc_utils import PROJECT_DIR
import model_training
import model_eval

os.chdir(PROJECT_DIR) # changing our directory to root

# %%
df_big_data = pd.read_csv('data/big_data_processed_train_val_one_sec.csv')
df_big_argumented_data = pd.read_csv('data/big_argumentation_data_train_val_one_sec.csv')
df = pd.concat([df_big_data, df_big_argumented_data], ignore_index=True)
df.tail()
# Out:
#        Unnamed: 0                                       file_path  label
# 89379       65625  data/big_data_upsample_train_and_val/65625.wav     65
# 89380       65626  data/big_data_upsample_train_and_val/65626.wav     65
# 89381       65627  data/big_data_upsample_train_and_val/65627.wav     65
# 89382       65628  data/big_data_upsample_train_and_val/65628.wav     65
# 89383       65629  data/big_data_upsample_train_and_val/65629.wav     65

# %%
# import json

# with open('audio_preprocessing/saved_data/upsampled_data_size_128_512_train_val_one_sec.json') as f:
#     my_info = json.load(f)

# mean, std, class_weights = my_info["mean"], my_info["std"], my_info["weights"]

# %%
train_df_list = []
val_df_list = []

for i in range(66):
    my_df = df[df["label"] == i]
    current_train_df, current_val_df = train_test_split(my_df, test_size=0.2)
    train_df_list.append(current_train_df)
    val_df_list.append(current_val_df)

df_train = pd.concat(train_df_list, ignore_index=True)
df_val = pd.concat(val_df_list, ignore_index=True)

# %%
df_train.shape, df_val.shape
# Out:
# ((71481, 3), (17903, 3))

# %%
# paths, labels = list(df_train["file_path"]), list(df_train["label"])

# non_normal_gen = preprocessing_func_3.non_normalised_data_generator(
#     paths=paths,
#     labels=labels,
# #     image_preprocess_fn=resize_function(output_shape=(40,256)),
# #     mel_transform_fn=calculate_melsp
# )

# %%
# mean, std, class_wights = preprocessing_func_3.get_stats_and_class_weights_of_non_normalised_data_gen(
#     non_normal_gen, (128, 512))

# %%
mean, std
# Out:
# (tensor([-1.1211]), tensor([0.7912]))

# %%
# import json

# def save_as_json(path, description, mean, std, weights):
#     my_dict = {
#         "description": description,
#         "mean": float(mean),
#         "std": float(std),
#         "weights": list(class_wights.astype(float)),
#     }
#     with open(path, 'w') as f:
#         json.dump(my_dict, f)

# save_as_json(
#     "audio_preprocessing/saved_data/upsampled_data_size_128_512_train_and_val.json", 
#     "seconds 1.5, image shape (128,512)", mean, std, class_wights)

# %%
train_dataset = NormalisedDataSet(
    non_normalised_data_generator_fn=preprocessing_func_3.non_normalised_data_generator, 
    normalised_data_generator_fn=preprocessing_func_3.normalised_data_generator,
    df=df_train, 
    mean=mean,
    std=std,
    shuffle=True
)

val_dataset = NormalisedDataSet(
    non_normalised_data_generator_fn=preprocessing_func_3.non_normalised_data_generator, 
    normalised_data_generator_fn=preprocessing_func_3.normalised_data_generator,
    df=df_val, 
    mean=mean,
    std=std,
    shuffle=False
)

train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=28)
val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size=28)

# %%
device = model_training.get_device()

# %%
from torchvision.models import regnet_y_3_2gf
import torch.optim as optim
import torch.nn as nn

#resnet_model = resnet34(weights=ResNet34_Weights.DEFAULT)
regnet_model = regnet_y_3_2gf(num_classes=66)
regnet_model.stem[0] = nn.Conv2d(1, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
regnet_model = regnet_model.to(device)

# %%
print(regnet_model)
# Out:
# RegNet(
#   (stem): SimpleStemIN(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (trunk_output): Sequential(
#     (block1): AnyStage(
#       (block1-0): ResBottleneckBlock(
#         (proj): Conv2dNormActivation(
#           (0): Conv2d(32, 72, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(32, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(72, 72, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=3, bias=False)
#             (1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (se): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(72, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 72, kernel_size=(1, 1), stride=(1, 1))
#             (activation): ReLU()
#             (scale_activation): Sigmoid()
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(72, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block1-1): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(72, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(72, 72, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=3, bias=False)
#             (1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (se): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(72, 18, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(18, 72, kernel_size=(1, 1), stride=(1, 1))
#             (activation): ReLU()
#             (scale_activation): Sigmoid()
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(72, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#     )
#     (block2): AnyStage(
#       (block2-0): ResBottleneckBlock(
#         (proj): Conv2dNormActivation(
#           (0): Conv2d(72, 216, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(72, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(216, 216, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=9, bias=False)
#             (1): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (se): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(216, 18, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(18, 216, kernel_size=(1, 1), stride=(1, 1))
#             (activation): ReLU()
#             (scale_activation): Sigmoid()
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block2-1): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(216, 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=9, bias=False)
#             (1): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (se): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(216, 54, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(54, 216, kernel_size=(1, 1), stride=(1, 1))
#             (activation): ReLU()
#             (scale_activation): Sigmoid()
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block2-2): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(216, 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=9, bias=False)
#             (1): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (se): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(216, 54, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(54, 216, kernel_size=(1, 1), stride=(1, 1))
#             (activation): ReLU()
#             (scale_activation): Sigmoid()
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block2-3): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(216, 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=9, bias=False)
#             (1): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (se): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(216, 54, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(54, 216, kernel_size=(1, 1), stride=(1, 1))
#             (activation): ReLU()
#             (scale_activation): Sigmoid()
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block2-4): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(216, 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=9, bias=False)
#             (1): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (se): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(216, 54, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(54, 216, kernel_size=(1, 1), stride=(1, 1))
#             (activation): ReLU()
#             (scale_activation): Sigmoid()
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(216, 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#     )
#     (block3): AnyStage(
#       (block3-0): ResBottleneckBlock(
#         (proj): Conv2dNormActivation(
#           (0): Conv2d(216, 576, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(216, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=24, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (se): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(576, 54, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(54, 576, kernel_size=(1, 1), stride=(1, 1))
#             (activation): ReLU()
#             (scale_activation): Sigmoid()
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block3-1): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (se): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(576, 144, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(144, 576, kernel_size=(1, 1), stride=(1, 1))
#             (activation): ReLU()
#             (scale_activation): Sigmoid()
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block3-2): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (se): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(576, 144, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(144, 576, kernel_size=(1, 1), stride=(1, 1))
#             (activation): ReLU()
#             (scale_activation): Sigmoid()
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block3-3): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (se): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(576, 144, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(144, 576, kernel_size=(1, 1), stride=(1, 1))
#             (activation): ReLU()
#             (scale_activation): Sigmoid()
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block3-4): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (se): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(576, 144, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(144, 576, kernel_size=(1, 1), stride=(1, 1))
#             (activation): ReLU()
#             (scale_activation): Sigmoid()
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block3-5): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (se): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(576, 144, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(144, 576, kernel_size=(1, 1), stride=(1, 1))
#             (activation): ReLU()
#             (scale_activation): Sigmoid()
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block3-6): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (se): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(576, 144, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(144, 576, kernel_size=(1, 1), stride=(1, 1))
#             (activation): ReLU()
#             (scale_activation): Sigmoid()
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block3-7): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (se): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(576, 144, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(144, 576, kernel_size=(1, 1), stride=(1, 1))
#             (activation): ReLU()
#             (scale_activation): Sigmoid()
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block3-8): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (se): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(576, 144, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(144, 576, kernel_size=(1, 1), stride=(1, 1))
#             (activation): ReLU()
#             (scale_activation): Sigmoid()
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block3-9): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (se): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(576, 144, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(144, 576, kernel_size=(1, 1), stride=(1, 1))
#             (activation): ReLU()
#             (scale_activation): Sigmoid()
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block3-10): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (se): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(576, 144, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(144, 576, kernel_size=(1, 1), stride=(1, 1))
#             (activation): ReLU()
#             (scale_activation): Sigmoid()
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block3-11): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (se): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(576, 144, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(144, 576, kernel_size=(1, 1), stride=(1, 1))
#             (activation): ReLU()
#             (scale_activation): Sigmoid()
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#       (block3-12): ResBottleneckBlock(
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (se): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(576, 144, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(144, 576, kernel_size=(1, 1), stride=(1, 1))
#             (activation): ReLU()
#             (scale_activation): Sigmoid()
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(576, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#     )
#     (block4): AnyStage(
#       (block4-0): ResBottleneckBlock(
#         (proj): Conv2dNormActivation(
#           (0): Conv2d(576, 1512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (f): BottleneckTransform(
#           (a): Conv2dNormActivation(
#             (0): Conv2d(576, 1512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (b): Conv2dNormActivation(
#             (0): Conv2d(1512, 1512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=63, bias=False)
#             (1): BatchNorm2d(1512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace=True)
#           )
#           (se): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1512, 144, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(144, 1512, kernel_size=(1, 1), stride=(1, 1))
#             (activation): ReLU()
#             (scale_activation): Sigmoid()
#           )
#           (c): Conv2dNormActivation(
#             (0): Conv2d(1512, 1512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (activation): ReLU(inplace=True)
#       )
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=1512, out_features=66, bias=True)
# )

# %%
optimizer = optim.Adam(regnet_model.parameters(), amsgrad=True)
loss = nn.CrossEntropyLoss()

# %%
model_training.training(
    model=regnet_model, 
    optimizer=optimizer, 
    loss_fn=loss, 
    train_dataloader=train_dataloader, 
    val_dataloader=val_dataloader, 
    model_path="models/regnet_y_3_2gf_train_and_val", 
    start_epoch=0,
    epochs=500,
    early_stop_thresh=50,
)
# Out:
# End of epoch 0: training accuracy = 68.20%, training loss = 1.0768036263868288, training time taken = 889.99 seconds
# End of epoch 0: validation accuracy = 87.39%, validation loss = 0.39692815522648744, validation time taken = 255.03 seconds
# End of epoch 1: training accuracy = 90.09%, training loss = 0.3175352533715254, training time taken = 888.53 seconds
# End of epoch 1: validation accuracy = 92.76%, validation loss = 0.22927062902401757, validation time taken = 193.67 seconds
# End of epoch 2: training accuracy = 93.84%, training loss = 0.19049452508170825, training time taken = 891.19 seconds
# End of epoch 2: validation accuracy = 95.10%, validation loss = 0.14930551547325416, validation time taken = 192.69 seconds
# End of epoch 3: training accuracy = 95.68%, training loss = 0.1358780658182725, training time taken = 891.00 seconds
# End of epoch 3: validation accuracy = 96.53%, validation loss = 0.11330742101380054, validation time taken = 191.91 seconds
# End of epoch 4: training accuracy = 96.66%, training loss = 0.10348672526151663, training time taken = 887.98 seconds
# End of epoch 4: validation accuracy = 96.34%, validation loss = 0.11826190877368745, validation time taken = 193.34 seconds
# End of epoch 5: training accuracy = 97.44%, training loss = 0.07854809524585182, training time taken = 929.11 seconds
# End of epoch 5: validation accuracy = 96.55%, validation loss = 0.11070899186644781, validation time taken = 201.16 seconds
# End of epoch 6: training accuracy = 97.87%, training loss = 0.06663857764679183, training time taken = 1066.94 seconds
# End of epoch 6: validation accuracy = 96.91%, validation loss = 0.09839760909653136, validation time taken = 231.14 seconds
# End of epoch 7: training accuracy = 98.22%, training loss = 0.05466550167352642, training time taken = 909.12 seconds
# End of epoch 7: validation accuracy = 97.08%, validation loss = 0.09385982817618163, validation time taken = 192.10 seconds
# End of epoch 8: training accuracy = 98.52%, training loss = 0.0448580926614368, training time taken = 889.70 seconds
# End of epoch 8: validation accuracy = 97.45%, validation loss = 0.0859192701978773, validation time taken = 193.01 seconds
# End of epoch 9: training accuracy = 98.85%, training loss = 0.03601888078600903, training time taken = 892.82 seconds
# End of epoch 9: validation accuracy = 97.43%, validation loss = 0.08327650439238013, validation time taken = 189.99 seconds
# End of epoch 10: training accuracy = 98.99%, training loss = 0.03269890139557801, training time taken = 893.40 seconds
# End of epoch 10: validation accuracy = 97.61%, validation loss = 0.07976077703718207, validation time taken = 191.49 seconds
# End of epoch 11: training accuracy = 99.12%, training loss = 0.02696694272830249, training time taken = 885.07 seconds
# End of epoch 11: validation accuracy = 97.88%, validation loss = 0.07170666826219171, validation time taken = 194.55 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 model_training.training(
#       2     model=regnet_model,
#       3     optimizer=optimizer,
#       4     loss_fn=loss,
#       5     train_dataloader=train_dataloader,
#       6     val_dataloader=val_dataloader,
#       7     model_path="models/regnet_y_3_2gf_train_and_val",
#       8     start_epoch=0,
#       9     epochs=500,
#      10     early_stop_thresh=50,
#      11 )
#
# File ~\AnacondaProjects\insects_classification\model_definition_and_training\regnet_y_3_2gf\../../model_training_utils\model_training.py:55, in training(model, optimizer, loss_fn, train_dataloader, val_dataloader, model_path, epochs, early_stop_thresh, lr_decay, device, start_epoch)
#      52 training_start_time = time.time()
#      54 # training loop
# ---> 55 for x_batch, y_batch in train_dataloader:
#      56     x_batch = x_batch.to(device, dtype=torch.float32)
#      57     y_batch = y_batch.to(device, dtype=torch.long)
#
# File ~\anaconda3\envs\torch\Lib\site-packages\torch\utils\data\dataloader.py:633, in _BaseDataLoaderIter.__next__(self)
#     630 if self._sampler_iter is None:
#     631     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     632     self._reset()  # type: ignore[call-arg]
# --> 633 data = self._next_data()
#     634 self._num_yielded += 1
#     635 if self._dataset_kind == _DatasetKind.Iterable and \
#     636         self._IterableDataset_len_called is not None and \
#     637         self._num_yielded > self._IterableDataset_len_called:
#
# File ~\anaconda3\envs\torch\Lib\site-packages\torch\utils\data\dataloader.py:677, in _SingleProcessDataLoaderIter._next_data(self)
#     675 def _next_data(self):
#     676     index = self._next_index()  # may raise StopIteration
# --> 677     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     678     if self._pin_memory:
#     679         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~\anaconda3\envs\torch\Lib\site-packages\torch\utils\data\_utils\fetch.py:32, in _IterableDatasetFetcher.fetch(self, possibly_batched_index)
#      30 for _ in possibly_batched_index:
#      31     try:
# ---> 32         data.append(next(self.dataset_iter))
#      33     except StopIteration:
#      34         self.ended = True
#
# File ~\AnacondaProjects\insects_classification\model_definition_and_training\regnet_y_3_2gf\../../audio_preprocessing\preprocessing_func_3.py:76, in normalised_data_generator(generator, mean, std)
#      64 def normalised_data_generator(generator, mean, std):
#      65     """
#      66     Return a generator with normalised images.
#      67
#    (...)
#      74         generator outputing (normalised image with mean 0 and std 1, label)
#      75     """
# ---> 76     for image, label in generator:
#      77         yield normalise_image(image, mean, std), label
#
# File ~\AnacondaProjects\insects_classification\model_definition_and_training\regnet_y_3_2gf\../../audio_preprocessing\preprocessing_func_3.py:44, in non_normalised_data_generator(paths, labels, image_preprocess_fn, mel_transform_fn, wav_max_amplitude)
#      42 for (path, label) in zip(paths, labels):
#      43     wav = load_wav(path=path)
# ---> 44     db_mel_spec = mel_transform_fn(wav)
#      45     db_mel_spec = to_reshaped_tensor(db_mel_spec)
#      46     yield image_preprocess_fn(db_mel_spec), label
#
# File ~\AnacondaProjects\insects_classification\model_definition_and_training\regnet_y_3_2gf\../../audio_preprocessing\preprocessing_func_3.py:26, in calculate_melsp(x, n_fft, hop_length)
#      25 def calculate_melsp(x, n_fft=1024, hop_length=128):
# ---> 26     stft = np.abs(librosa.stft(x, n_fft=n_fft, hop_length=hop_length))**2
#      27     log_stft = librosa.power_to_db(stft)
#      28     melsp = librosa.feature.melspectrogram(S=log_stft,n_mels=128)
#
# File ~\anaconda3\envs\torch\Lib\site-packages\librosa\core\spectrum.py:377, in stft(y, n_fft, hop_length, win_length, window, center, dtype, pad_mode, out)
#     374 for bl_s in range(0, y_frames.shape[-1], n_columns):
#     375     bl_t = min(bl_s + n_columns, y_frames.shape[-1])
# --> 377     stft_matrix[..., bl_s + off_start : bl_t + off_start] = fft.rfft(
#     378         fft_window * y_frames[..., bl_s:bl_t], axis=-2
#     379     )
#     380 return stft_matrix
#
# KeyboardInterrupt:

# %%
torch.save(regnet_model, 'models/regnet_y_3_2gf_train_and_val/regnet_model_epoch_11.pth')
